# %%
# %pylab inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
fileURL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
data = pd.read_csv(fileURL, names=['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width', 'Name'], header=None)

# %%
#Print the first 5 elements
data.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width         Name
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#Compute and display summary statistics for each feature available in the dataset
data.describe()
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#variance
data.var()
# Out:
# Sepal Length    0.685694
# Sepal Width     0.188004
# Petal Length    3.113179
# Petal Width     0.582414
# dtype: float64

# %%
sl = data['Sepal Length']

# %%
#create a histogram for Sepal Length
slhist = sl.hist()

# %%
sw = data['Sepal Width']

# %%
#create a histogram for Sepal Width
swhist = sw.hist()

# %%
pl = data['Petal Length']

# %%
#create a histogram for Petal Length
plhist = pl.hist()

# %%
pw = data['Petal Width']

# %%
##create a histogram for Petal Width
pwhist = pw.hist()

# %%
#create a boxplot for each feature in the dataset
box = data.boxplot(grid=False, return_type='axes')

# %%
#same process on another dataset
penbased = pd.read_csv('/Users/chuzhan/Downloads/pendigits.tra')

# %%
penbased.head()
# Out:
#     47  100   27   81   57   37   26    0    0.1   23   56   53  100.1   90  \
# 0    0   89   27  100   42   75   29   45     15   15   37    0     69    2
# 1    0   57   31   68   72   90  100  100     76   75   50   51     28   25
# 2    0  100    7   92    5   68   19   45     86   34  100   45     74   23
# 3    0   67   49   83  100  100   81   80     60   60   40   40     33   20
# 4  100  100   88   99   49   74   17   47      0   16   37    0     73   16
#
#     40   98   8
# 0  100    6   2
# 1   16    0   1
# 2   67    0   4
# 3   47    0   1
# 4   20   20   6

# %%
penbased.describe()
# Out:
#                 47          100           27           81           57  \
# count  7493.000000  7493.000000  7493.000000  7493.000000  7493.000000
# mean     37.383024    84.677299    40.007340    82.889764    50.877486
# std      33.324063    16.848615    26.257347    19.639880    34.929460
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000    76.000000    20.000000    70.000000    17.000000
# 50%      31.000000    89.000000    39.000000    89.000000    56.000000
# 75%      61.000000   100.000000    58.000000   100.000000    81.000000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
#
#                 37           26            0          0.1           23  \
# count  7493.000000  7493.000000  7493.000000  7493.000000  7493.000000
# mean     65.048178    51.475244    44.605632    57.137595    34.070599
# std      27.377250    30.680711    30.657194    33.676120    27.461524
# ...

# %%
penbased.var()
# Out:
#  47      1110.493155
# 100       283.875829
#  27       689.448291
#  81       385.724899
#  57      1220.067209
#  37       749.513829
#  26       941.306014
#   0       939.863540
#   0.1    1134.081038
#  23       754.135298
#  56      1378.873601
#  53       756.082309
# 100.1     510.544324
#  90      1103.563482
#  40      1725.113924
#  98      1281.962046
#  8          8.276422
# dtype: float64

# %%
penbased.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x114601d30>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112c72208>]], dtype=object)

# %%
penbox = penbased.boxplot(grid=False, return_type='axes')

# %%
#3.1How do the shapes of the histograms for petal length and petal width 
#   differ from those for sepal length and sepal width? 
# Answer: petal length & width has an obvious descresement in the third bar, while sepal length & width are more like  
# the type that increase to the peak then decrease(more like nomial bell shape)

#3.2 Is there a particular value of petal length where the distribution of petal lengths
#    could be best segmented into two parts?
#Answer: Yes, the value is 2

#3.3 Based upon these boxplots, is there a pair of features that appear to have significantly different medians? 
#Answer: Yes, is Sepal Length and Petal Width

#3.4 Based solely upon the box plots, which feature appears to explain the greatest amount of the data?
#Answer: Petal Length

#3.5 Do you observe any outliers? If so, for what features?
#Answer: Yes. Feature 100 & 81 have many outliers. 

#3.6 What sort of distribution do the second and fourth features display? 
#Answer: Left skewed graphsy
